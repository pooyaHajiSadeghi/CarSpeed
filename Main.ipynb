# %%
! pip install -r requirements.txt
# Out:
# Requirement already satisfied: opencv-python in c:\users\phs\appdata\local\programs\python\python311\lib\site-packages (from -r requirements.txt (line 1)) (4.11.0.86)
# Requirement already satisfied: ultralytics in c:\users\phs\appdata\local\programs\python\python311\lib\site-packages (from -r requirements.txt (line 2)) (8.3.103)
# Requirement already satisfied: numpy in c:\users\phs\appdata\local\programs\python\python311\lib\site-packages (from -r requirements.txt (line 3)) (1.25.0)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\phs\appdata\local\programs\python\python311\lib\site-packages (from ultralytics->-r requirements.txt (line 2)) (3.9.2)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\phs\appdata\local\programs\python\python311\lib\site-packages (from ultralytics->-r requirements.txt (line 2)) (10.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\phs\appdata\local\programs\python\python311\lib\site-packages (from ultralytics->-r requirements.txt (line 2)) (6.0)
# Requirement already satisfied: requests>=2.23.0 in c:\users\phs\appdata\local\programs\python\python311\lib\site-packages (from ultralytics->-r requirements.txt (line 2)) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\phs\appdata\local\programs\python\python311\lib\site-packages (from ultralytics->-r requirements.txt (line 2)) (1.14.1)
# Requirement already satisfied: torch>=1.8.0 in c:\users\phs\appdata\local\programs\python\python311\lib\site-packages (from ultralytics->-r requirements.txt (line 2)) (2.6.0)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\phs\appdata\local\programs\python\python311\lib\site-packages (from ultralytics->-r requirements.txt (line 2)) (0.21.0)
# Requirement already satisfied: tqdm>=4.64.0 in c:\users\phs\appdata\local\programs\python\python311\lib\site-packages (from ultralytics->-r requirements.txt (line 2)) (4.67.1)
# Requirement already satisfied: psutil in c:\users\phs\appdata\roaming\python\python311\site-packages (from ultralytics->-r requirements.txt (line 2)) (5.9.5)
# Requirement already satisfied: py-cpuinfo in c:\users\phs\appdata\local\programs\python\python311\lib\site-packages (from ultralytics->-r requirements.txt (line 2)) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\phs\appdata\local\programs\python\python311\lib\site-packages (from ultralytics->-r requirements.txt (line 2)) (2.0.2)
# Requirement already satisfied: seaborn>=0.11.0 in c:\users\phs\appdata\local\programs\python\python311\lib\site-packages (from ultralytics->-r requirements.txt (line 2)) (0.13.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in c:\users\phs\appdata\local\programs\python\python311\lib\site-packages (from ultralytics->-r requirements.txt (line 2)) (2.0.14)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\phs\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.3.0->ultralytics->-r requirements.txt (line 2)) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\phs\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.3.0->ultralytics->-r requirements.txt (line 2)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\phs\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.3.0->ultralytics->-r requirements.txt (line 2)) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\phs\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.3.0->ultralytics->-r requirements.txt (line 2)) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\phs\appdata\roaming\python\python311\site-packages (from matplotlib>=3.3.0->ultralytics->-r requirements.txt (line 2)) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\phs\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.3.0->ultralytics->-r requirements.txt (line 2)) (3.1.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\phs\appdata\roaming\python\python311\site-packages (from matplotlib>=3.3.0->ultralytics->-r requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\phs\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.1.4->ultralytics->-r requirements.txt (line 2)) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\phs\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.1.4->ultralytics->-r requirements.txt (line 2)) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\phs\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.23.0->ultralytics->-r requirements.txt (line 2)) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\phs\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.23.0->ultralytics->-r requirements.txt (line 2)) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\phs\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.23.0->ultralytics->-r requirements.txt (line 2)) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\phs\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.23.0->ultralytics->-r requirements.txt (line 2)) (2023.7.22)
# Requirement already satisfied: filelock in c:\users\phs\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.8.0->ultralytics->-r requirements.txt (line 2)) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\phs\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.8.0->ultralytics->-r requirements.txt (line 2)) (4.13.1)
# Requirement already satisfied: networkx in c:\users\phs\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.8.0->ultralytics->-r requirements.txt (line 2)) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\phs\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.8.0->ultralytics->-r requirements.txt (line 2)) (3.1.2)
# Requirement already satisfied: fsspec in c:\users\phs\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.8.0->ultralytics->-r requirements.txt (line 2)) (2025.3.2)
# Requirement already satisfied: sympy==1.13.1 in c:\users\phs\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.8.0->ultralytics->-r requirements.txt (line 2)) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\phs\appdata\local\programs\python\python311\lib\site-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics->-r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: colorama in c:\users\phs\appdata\roaming\python\python311\site-packages (from tqdm>=4.64.0->ultralytics->-r requirements.txt (line 2)) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\phs\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics->-r requirements.txt (line 2)) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\phs\appdata\local\programs\python\python311\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics->-r requirements.txt (line 2)) (2.1.3)

# %%
from collections import defaultdict
from time import time

import cv2
import numpy as np

from ultralytics.utils.checks import check_imshow
from ultralytics.utils.plotting import Annotator, colors


from ultralytics import YOLO

# %%
class SpeedEstimator:
    """A class to estimate the speed of objects in a real-time video stream based on their tracks."""

    def __init__(self, names, reg_pts=None, view_img=False, line_thickness=2, spdl_dist_thresh=10):
        """
        Initializes the SpeedEstimator with the given parameters.

        Args:
            names (dict): Dictionary of class names.
            reg_pts (list, optional): List of region points for speed estimation. Defaults to [(20, 400), (1260, 400)].
            view_img (bool, optional): Whether to display the image with annotations. Defaults to False.
            line_thickness (int, optional): Thickness of the lines for drawing boxes and tracks. Defaults to 2.
            spdl_dist_thresh (int, optional): Distance threshold for speed calculation. Defaults to 10.
        """
        # Region information
        self.reg_pts = reg_pts if reg_pts is not None else [(20, 400), (1260, 400)]

        self.names = names  # Classes names

        # Tracking information
        self.trk_history = defaultdict(list)

        self.view_img = view_img  # bool for displaying inference
        self.tf = line_thickness  # line thickness for annotator
        self.spd = {}  # set for speed data
        self.trkd_ids = []  # list for already speed_estimated and tracked ID's
        self.spdl = spdl_dist_thresh  # Speed line distance threshold
        self.trk_pt = {}  # set for tracks previous time
        self.trk_pp = {}  # set for tracks previous point

        # Check if the environment supports imshow
        self.env_check = check_imshow(warn=True)

    def estimate_speed(self, im0, tracks):
        """
        Estimates the speed of objects based on tracking data.

        Args:
            im0 (ndarray): Image.
            tracks (list): List of tracks obtained from the object tracking process.

        Returns:
            (ndarray): The image with annotated boxes and tracks.
        """
        if tracks[0].boxes.id is None:
            return im0
       
        boxes = tracks[0].boxes.xyxy.cpu()
        clss = tracks[0].boxes.cls.cpu().tolist()
        t_ids = tracks[0].boxes.id.int().cpu().tolist()
        annotator = Annotator(im0, line_width=self.tf)
        cv2.line(im0, self.reg_pts[0], self.reg_pts[1], (255, 0, 255), self.tf * 2)

        for box, t_id, cls in zip(boxes, t_ids, clss):
            
            track = self.trk_history[t_id]
            bbox_center = (float((box[0] + box[2]) / 2), float((box[1] + box[3]) / 2))
            track.append(bbox_center)

            if len(track) > 30:
                track.pop(0)

            trk_pts = np.hstack(track).astype(np.int32).reshape((-1, 1, 2))

            if t_id not in self.trk_pt:
                self.trk_pt[t_id] = 0

            speed_label = f"{int(self.spd[t_id])} km/h" if t_id in self.spd else self.names[int(cls)]
            bbox_color = colors(int(t_id), True)

            annotator.box_label(box, speed_label, bbox_color)
            cv2.polylines(im0, [trk_pts], isClosed=False, color=bbox_color, thickness=self.tf)
            cv2.circle(im0, (int(track[-1][0]), int(track[-1][1])), self.tf * 2, bbox_color, -1)

            # Calculation of object speed
            if not self.reg_pts[0][0] < track[-1][0] < self.reg_pts[1][0]:
                return
            if self.reg_pts[1][1] - self.spdl < track[-1][1] < self.reg_pts[1][1] + self.spdl:
                direction = "known"
            elif self.reg_pts[0][1] - self.spdl < track[-1][1] < self.reg_pts[0][1] + self.spdl:
                direction = "known"
            else:
                direction = "unknown"

            if self.trk_pt.get(t_id) != 0 and direction != "unknown" and t_id not in self.trkd_ids:
                self.trkd_ids.append(t_id)

                time_difference = time() - self.trk_pt[t_id]
                if time_difference > 0:
                    self.spd[t_id] = np.abs(track[-1][1] - self.trk_pp[t_id][1]) / time_difference

            self.trk_pt[t_id] = time()
            self.trk_pp[t_id] = track[-1]

        if self.view_img and self.env_check:
            cv2.imshow("Ultralytics Speed Estimation", im0)
            if cv2.waitKey(1) & 0xFF == ord("q"):
                return

        return im0


if __name__ == "__main__":
    names = {0: "person", 1: "car"}  # example class names
    speed_estimator = SpeedEstimator(names)

# %%
# Load YOLOv8 model
model = YOLO("yolov10n.pt")
# Initialize global variable to store cursor coordinates
line_pts = [(0, 288), (1019, 288)]
names = model.model.names  # This is a dictionary

speed_obj = SpeedEstimator(reg_pts=line_pts, names=names)

# Mouse callback function to capture mouse movement
def RGB(event, x, y, flags, param):
    global cursor_point
    if event == cv2.EVENT_MOUSEMOVE:
        cursor_point = (x, y)
        print(f"Mouse coordinates: {cursor_point}")

# Set up the window and attach the mouse callback function
cv2.namedWindow('RGB')
cv2.setMouseCallback('RGB', RGB)

# Open the video file or webcam feed
cap = cv2.VideoCapture('car.mp4')

count = 0
while True:
    ret, frame = cap.read()

    if not ret:
        print("Video stream ended or cannot be read.")
        break

    count += 1
    if count % 3 != 0:  # Skip some frames for speed (optional)
        continue

    frame = cv2.resize(frame, (1020, 500))
    
    # Perform object tracking
    tracks = model.track(frame, persist=True,classes=[2])
    
    
    im0 = speed_obj.estimate_speed(frame,tracks)
    
    # Display the frame with YOLOv8 results
    cv2.imshow("RGB", frame)

    if cv2.waitKey(1) & 0xFF == ord("q"):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 320x640 9 cars, 88.0ms
# Speed: 4.8ms preprocess, 88.0ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
# Mouse coordinates: (808, 87)
# Mouse coordinates: (808, 88)
#
# 0: 320x640 8 cars, 89.4ms
# Speed: 1.9ms preprocess, 89.4ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
# Mouse coordinates: (806, 90)
#
# 0: 320x640 8 cars, 80.8ms
# Speed: 2.1ms preprocess, 80.8ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
# Mouse coordinates: (805, 91)
#
# 0: 320x640 8 cars, 82.0ms
# Speed: 1.9ms preprocess, 82.0ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 80.9ms
# Speed: 1.9ms preprocess, 80.9ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 77.8ms
# Speed: 2.4ms preprocess, 77.8ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 78.1ms
# Speed: 2.6ms preprocess, 78.1ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 77.0ms
# Speed: 2.4ms preprocess, 77.0ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 80.4ms
# Speed: 2.8ms preprocess, 80.4ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 86.9ms
# Speed: 1.9ms preprocess, 86.9ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
# Mouse coordinates: (802, 95)
#
# 0: 320x640 7 cars, 79.9ms
# Speed: 3.5ms preprocess, 79.9ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
# Mouse coordinates: (801, 96)
#
# 0: 320x640 7 cars, 74.5ms
# Speed: 1.8ms preprocess, 74.5ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
# Mouse coordinates: (800, 98)
#
# 0: 320x640 8 cars, 78.2ms
# Speed: 2.0ms preprocess, 78.2ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
# Mouse coordinates: (799, 100)
#
# 0: 320x640 8 cars, 80.2ms
# Speed: 3.3ms preprocess, 80.2ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
# Mouse coordinates: (797, 102)
#
# 0: 320x640 8 cars, 73.7ms
# Speed: 3.0ms preprocess, 73.7ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 80.0ms
# Speed: 1.9ms preprocess, 80.0ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
# Mouse coordinates: (791, 109)
# Mouse coordinates: (791, 109)
#
# 0: 320x640 7 cars, 84.1ms
# Speed: 2.3ms preprocess, 84.1ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 110.5ms
# Speed: 1.9ms preprocess, 110.5ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 83.4ms
# Speed: 2.0ms preprocess, 83.4ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 78.9ms
# Speed: 3.1ms preprocess, 78.9ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 81.4ms
# Speed: 2.3ms preprocess, 81.4ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 80.0ms
# Speed: 1.7ms preprocess, 80.0ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 71.5ms
# Speed: 2.0ms preprocess, 71.5ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 82.7ms
# Speed: 2.7ms preprocess, 82.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 77.0ms
# Speed: 2.5ms preprocess, 77.0ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 79.7ms
# Speed: 2.8ms preprocess, 79.7ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 75.3ms
# Speed: 2.8ms preprocess, 75.3ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 78.9ms
# Speed: 2.5ms preprocess, 78.9ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 75.7ms
# Speed: 3.6ms preprocess, 75.7ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 72.9ms
# Speed: 2.2ms preprocess, 72.9ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 73.1ms
# Speed: 2.6ms preprocess, 73.1ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 73.9ms
# Speed: 3.6ms preprocess, 73.9ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 78.6ms
# Speed: 2.7ms preprocess, 78.6ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 73.7ms
# Speed: 3.3ms preprocess, 73.7ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 77.0ms
# Speed: 2.4ms preprocess, 77.0ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 75.4ms
# Speed: 4.0ms preprocess, 75.4ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 76.4ms
# Speed: 2.3ms preprocess, 76.4ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 82.3ms
# Speed: 2.8ms preprocess, 82.3ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 77.0ms
# Speed: 2.9ms preprocess, 77.0ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
# Mouse coordinates: (790, 109)
#
# 0: 320x640 4 cars, 77.6ms
# Speed: 2.0ms preprocess, 77.6ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 78.0ms
# Speed: 3.7ms preprocess, 78.0ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 108.0ms
# Speed: 3.0ms preprocess, 108.0ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
# Mouse coordinates: (790, 112)
#
# 0: 320x640 4 cars, 84.1ms
# Speed: 2.0ms preprocess, 84.1ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
# Mouse coordinates: (788, 116)
#
# 0: 320x640 3 cars, 75.1ms
# Speed: 2.1ms preprocess, 75.1ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 cars, 80.2ms
# Speed: 2.9ms preprocess, 80.2ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 cars, 73.2ms
# Speed: 3.1ms preprocess, 73.2ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 cars, 82.3ms
# Speed: 2.8ms preprocess, 82.3ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 cars, 78.8ms
# Speed: 3.0ms preprocess, 78.8ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 cars, 78.1ms
# Speed: 3.1ms preprocess, 78.1ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 cars, 81.4ms
# Speed: 3.1ms preprocess, 81.4ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 cars, 78.5ms
# Speed: 2.3ms preprocess, 78.5ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 cars, 80.2ms
# Speed: 1.7ms preprocess, 80.2ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 cars, 73.2ms
# Speed: 2.5ms preprocess, 73.2ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 80.8ms
# Speed: 2.1ms preprocess, 80.8ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 79.8ms
# Speed: 3.1ms preprocess, 79.8ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 77.1ms
# Speed: 2.0ms preprocess, 77.1ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 75.5ms
# Speed: 2.0ms preprocess, 75.5ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 80.2ms
# Speed: 3.1ms preprocess, 80.2ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 79.3ms
# Speed: 2.7ms preprocess, 79.3ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 79.9ms
# Speed: 2.0ms preprocess, 79.9ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
# Mouse coordinates: (787, 117)
#
# 0: 320x640 5 cars, 74.2ms
# Speed: 2.0ms preprocess, 74.2ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 80.5ms
# Speed: 3.4ms preprocess, 80.5ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 76.9ms
# Speed: 3.2ms preprocess, 76.9ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 71.1ms
# Speed: 2.0ms preprocess, 71.1ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 77.8ms
# Speed: 3.5ms preprocess, 77.8ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 113.0ms
# Speed: 2.3ms preprocess, 113.0ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 76.7ms
# Speed: 2.5ms preprocess, 76.7ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 76.9ms
# Speed: 2.3ms preprocess, 76.9ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 81.5ms
# Speed: 3.1ms preprocess, 81.5ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 75.0ms
# Speed: 2.4ms preprocess, 75.0ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 cars, 78.2ms
# Speed: 2.7ms preprocess, 78.2ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 75.3ms
# Speed: 2.7ms preprocess, 75.3ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 78.9ms
# Speed: 2.3ms preprocess, 78.9ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 74.2ms
# Speed: 4.6ms preprocess, 74.2ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 72.4ms
# Speed: 2.1ms preprocess, 72.4ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 80.7ms
# Speed: 3.0ms preprocess, 80.7ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 80.4ms
# Speed: 2.2ms preprocess, 80.4ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 76.9ms
# Speed: 4.4ms preprocess, 76.9ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 71.7ms
# Speed: 3.4ms preprocess, 71.7ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 82.7ms
# Speed: 2.2ms preprocess, 82.7ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 80.5ms
# Speed: 3.6ms preprocess, 80.5ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 76.7ms
# Speed: 2.0ms preprocess, 76.7ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 77.7ms
# Speed: 3.5ms preprocess, 77.7ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars,
7ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 89.1ms
# Speed: 5.0ms preprocess, 89.1ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 81.7ms
# Speed: 2.9ms preprocess, 81.7ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 76.4ms
# Speed: 4.1ms preprocess, 76.4ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 78.0ms
# Speed: 3.6ms preprocess, 78.0ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 80.0ms
# Speed: 2.9ms preprocess, 80.0ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 88.8ms
# Speed: 2.8ms preprocess, 88.8ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 78.3ms
# Speed: 1.7ms preprocess, 78.3ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 73.0ms
# Speed: 3.4ms preprocess, 73.0ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 82.0ms
# Speed: 2.0ms preprocess, 82.0ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 75.8ms
# Speed: 3.5ms preprocess, 75.8ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 80.6ms
# Speed: 2.2ms preprocess, 80.6ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 75.9ms
# Speed: 1.9ms preprocess, 75.9ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 77.5ms
# Speed: 2.3ms preprocess, 77.5ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 72.7ms
# Speed: 2.2ms preprocess, 72.7ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 122.3ms
# Speed: 2.3ms preprocess, 122.3ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 78.9ms
# Speed: 2.4ms preprocess, 78.9ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 74.6ms
# Speed: 2.1ms preprocess, 74.6ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 74.9ms
# Speed: 3.6ms preprocess, 74.9ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 75.8ms
# Speed: 1.9ms preprocess, 75.8ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 77.4ms
# Speed: 2.4ms preprocess, 77.4ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 76.7ms
# Speed: 3.8ms preprocess, 76.7ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 73.5ms
# Speed: 4.4ms preprocess, 73.5ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 72.9ms
# Speed: 3.7ms preprocess, 72.9ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 79.8ms
# Speed: 3.6ms preprocess, 79.8ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 72.4ms
# Speed: 2.4ms preprocess, 72.4ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 77.3ms
# Speed: 3.2ms preprocess, 77.3ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 74.3ms
# Speed: 3.4ms preprocess, 74.3ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 86.0ms
# Speed: 2.3ms preprocess, 86.0ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 75.3ms
# Speed: 4.2ms preprocess, 75.3ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 74.7ms
# Speed: 1.8ms preprocess, 74.7ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 79.2ms
# Speed: 3.5ms preprocess, 79.2ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 79.3ms
# Speed: 2.0ms preprocess, 79.3ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 75.6ms
# Speed: 1.9ms preprocess, 75.6ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 78.6ms
# Speed: 2.1ms preprocess, 78.6ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 131.2ms
# Speed: 2.3ms preprocess, 131.2ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 74.3ms
# Speed: 3.4ms preprocess, 74.3ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 81.2ms
# Speed: 2.7ms preprocess, 81.2ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 76.8ms
# Speed: 3.5ms preprocess, 76.8ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 82.1ms
# Speed: 2.3ms preprocess, 82.1ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 78.0ms
# Speed: 3.9ms preprocess, 78.0ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 73.5ms
# Speed: 2.9ms preprocess, 73.5ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 80.7ms
# Speed: 2.6ms preprocess, 80.7ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 75.1ms
# Speed: 2.0ms preprocess, 75.1ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 76.3ms
# Speed: 4.6ms preprocess, 76.3ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 69.8ms
# Speed: 2.0ms preprocess, 69.8ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 75.9ms
# Speed: 2.7ms preprocess, 75.9ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 75.1ms
# Speed: 2.0ms preprocess, 75.1ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 72.3ms
# Speed: 4.1ms preprocess, 72.3ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 73.4ms
# Speed: 1.9ms preprocess, 73.4ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 76.4ms
# Speed: 3.3ms preprocess, 76.4ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 76.9ms
# Speed: 1.9ms preprocess, 76.9ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 75.1ms
# Speed: 3.2ms preprocess, 75.1ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 81.7ms
# Speed: 3.4ms preprocess, 81.7ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 70.8ms
# Speed: 2.1ms preprocess, 70.8ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 118.3ms
# Speed: 3.2ms preprocess, 118.3ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 77.5ms
# Speed: 2.6ms preprocess, 77.5ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 77.7ms
# Speed: 2.1ms preprocess, 77.7ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 77.7ms
# Speed: 2.8ms preprocess, 77.7ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 77.8ms
# Speed: 3.9ms preprocess, 77.8ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 80.7ms
# Speed: 2.8ms preprocess, 80.7ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 76.6ms
# Speed: 2.3ms preprocess, 76.6ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 78.5ms
# Speed: 3.0ms preprocess, 78.5ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 74.0ms
# Speed: 2.5ms preprocess, 74.0ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 80.6ms
# Speed: 3.3ms preprocess, 80.6ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 72.7ms
# Speed: 2.1ms preprocess, 72.7ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 79.0ms
# Speed: 1.7ms preprocess, 79.0ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 94.4ms
# Speed: 2.4ms preprocess, 94.4ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 80.4ms
# Speed: 3.8ms preprocess, 80.4ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
